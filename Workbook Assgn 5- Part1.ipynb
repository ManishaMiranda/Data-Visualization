# %%
import pandas as pd 
import numpy as np 
Location = r"C:\Users\maria\OneDrive\Documents\Data Visualization\datasets\gradedata.csv" 
df = pd.read_csv(Location) 
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#          fname      lname  gender  age  exercise  hours  grade  \
# 1978     Kiara       Lott  female   17         2     12   82.7
# 1235    Brenda      Gates  female   16         2      7   73.0
# 617     Cadman   Whitaker    male   18         5      4   67.8
# 1739  Chadwick    Harrell    male   17         1     12   90.3
# 1325     Chase  Blackwell    male   17         3     17   95.0
# ...        ...        ...     ...  ...       ...    ...    ...
# 1519     Brody     Duncan    male   15         4      9   76.4
# 89      Lucius    Herrera    male   14         2     19   88.0
# 611      Dante       Odom    male   18         3     10   79.9
# 1222     Devin  Rodriguez    male   19         1     14   83.4
# 1338  Vladimir      Casey    male   15         2     12   83.5
#
#                                            address
# 1978       7110 Ridge Road, Jacksonville, NC 28540
# 1235            8507 James Lane, Ontario, CA 91762
# 617        226 Tallwood Dr., Haines City, FL 33844
# 1739        55 Fieldstone Circle, Monroe, NY 10950
# 1325  8327 Manchester Lane, Huntersville, NC 28078
# ...                                            ...
# 1519         94 Lexington St., Ann Arbor, MI 48103
# 89              67 Old Clinton Dr., Lynn, MA 01902
# 611         448 Court Street, Maineville, OH 45039
# 1222         966 Pleasant Street, Hudson, NH 03051
# 1338              7810 Clay St., Holland, MI 49423
#
# [500 rows x 8 columns]
